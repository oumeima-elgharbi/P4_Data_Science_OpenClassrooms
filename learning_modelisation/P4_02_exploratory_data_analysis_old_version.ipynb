# %% [markdown]
# OpenClassrooms
# Project 4, Data Scientist
# Author : Oumeima EL GHARBI
# Date : August 2022

# %% [markdown]
# # PART 2 : Exploration of the dataset and Feature Engineering

# %% [markdown]
# ### Introduction

# %% [markdown]
# #### Idea :
#
# - The variable that we want to predict is : "TotalGHGEmissions"
#
# 1) Data visualization of "TotalGHGEmissions" and categorical features (like "BuildingType" for instance)
#     Feature Engineering : delete features that do not help for the prediction.
# 2) Study distribution of quantitative features (energy variables etc)
#     Feature Engineering :
#     - delete features that won't be useful for the prediction of "TotalGHGEmissions"
#     - apply transformations (log ? normalization ? etc skewness ??)
# 3) Correlation Matrix :
#     Feature Engineering : delete features that are correlated (repeeated features like kWh and kBtu).

# %% [markdown]
# #### **Conclusion** of the exploration and feature engineering :

# %%
print("Source Energy Accounts for Total Energy Use")
features_to_predict = [
    "SiteEnergyUse(kBtu)",
    "SteamUse(kBtu)",
    "Electricity(kBtu)",
    "NaturalGas(kBtu)",
    "TotalGHGEmissions"]

# pour prédire les 4 premieres : avec le meme groupe de var (utilisation des carstetiques des bat)

print("Features to predict : ", features_to_predict)
# Out:
# Source Energy Accounts for Total Energy Use
# Features to predict :  ['SiteEnergyUse(kBtu)', 'SteamUse(kBtu)', 'Electricity(kBtu)', 'NaturalGas(kBtu)', 'TotalGHGEmissions']

# %% [markdown]
# ### Starting exploration

# %% [markdown]
# #### Importing libraries

# %%
# %reset -f

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %autosave 300
# Out:
# Autosaving every 300 seconds

# %%
from functions import *

# %%
import os, warnings
# warnings.filterwarnings('ignore')
warnings.filterwarnings(action="once")

# %% [markdown]
# #### Loading dataset

# %%
columns_to_categorize = ["BuildingType", "PrimaryPropertyType", "Neighborhood", "ZipCode", "CouncilDistrictCode",
                         "LargestPropertyUseType", "SecondLargestPropertyUseType", "ThirdLargestPropertyUseType"]

category_types = {column: 'category' for column in columns_to_categorize}
print("This dictionary will be used when reading the csv file to assign a type to categorical features :",
      category_types)
# Out:
# This dictionary will be used when reading the csv file to assign a type to categorical features : {'BuildingType': 'category', 'PrimaryPropertyType': 'category', 'Neighborhood': 'category', 'ZipCode': 'category', 'CouncilDistrictCode': 'category', 'LargestPropertyUseType': 'category', 'SecondLargestPropertyUseType': 'category', 'ThirdLargestPropertyUseType': 'category'}

# %%
path = "./dataset/cleaned/"
filename = "2016_Building_Energy_Cleaned.csv"

dataset_path = "{}{}".format(path, filename)
# we assign the categorical features with a categotical type
dataset = pd.read_csv(dataset_path, dtype=category_types)

# %%
dataset.shape
# Out:
# (3157, 32)

# %%
dataset[:10]
# Out:
#    OSEBuildingID          BuildingType    PrimaryPropertyType  ZipCode  \
# 0          25006  Multifamily LR (1-4)   Low-Rise Multifamily  98112.0
# 1          25025        NonResidential              Warehouse  98144.0
# 2          25028  Multifamily LR (1-4)   Low-Rise Multifamily  98144.0
# 3          25046  Multifamily HR (10+)  High-Rise Multifamily  98144.0
# 4          25047  Multifamily LR (1-4)   Low-Rise Multifamily  98108.0
# 5          25002        NonResidential  Self-Storage Facility  98115.0
# 6          25053  Multifamily LR (1-4)   Low-Rise Multifamily  98115.0
# 7          25054  Multifamily LR (1-4)   Low-Rise Multifamily  98115.0
# 8          25055  Multifamily LR (1-4)   Low-Rise Multifamily  98103.0
# 9          25001        NonResidential  Self-Storage Facility  98115.0
#
#   CouncilDistrictCode      Neighborhood  YearBuilt  NumberofBuildings  \
# 0                   3           central       1978           1.000000
# 1                   3  greater duwamish       1928           1.000000
# 2                   2  greater duwamish       1925           1.000000
# 3                   2  greater duwamish       1971           1.000000
# 4                   2  greater duwamish       2001           1.000000
# 5                   4         northeast       1996           1.000000
# 6                   4         northeast       1972           1.000000
# 7                   4         northeast       1977           1.000000
# 8                   6         northwest       2006           1.000000
# 9                   4         northeast       1947           1.000000
#
#    NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0               3             20739                   0
# 1               2             25955                   0
# 2               3             25120                   0
# 3              15             73898                   0
# 4               3             36383                7030
# 5               4             38959                   0
# 6               2            136752                   0
# 7               3            120701                   0
# 8               4             54238                   0
# 9               3             22522                   0
#
#    PropertyGFABuilding(s)      LargestPropertyUseType  \
# 0                   20739         Multifamily Housing
# 1                   25955  Non-Refrigerated Warehouse
# 2                   25120         Multifamily Housing
# 3                   73898         Multifamily Housing
# 4                   29353         Multifamily Housing
# 5                   38959       Self-Storage Facility
# 6                  136752         Multifamily Housing
# 7                  120701         Multifamily Housing
# 8                   54238         Multifamily Housing
# 9                   22522       Self-Storage Facility
#
#    LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# 0               17628.000000                         None
# 1               14150.000000             Other - Services
# 2               25120.000000                         None
# 3               79912.000000                         None
# 4               25153.000000                       Office
# 5               38959.000000                         None
# 6              113227.000000                         None
# 7               98357.000000                      Parking
# 8               42377.000000                         None
# 9               22522.000000                         None
#
#    SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# 0                         0.000000                        None
# 1                      8745.000000                      Office
# 2                         0.000000                        None
# 3                         0.000000                        None
# 4                      4200.000000                     Parking
# 5                         0.000000                        None
# 6                         0.000000                        None
# 7                     15448.000000                        None
# 8                         0.000000                        None
# 9                         0.000000                        None
#
#    ThirdLargestPropertyUseTypeGFA  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 0                        0.000000        19.000000         46.299999
# 1                     3060.000000        -1.000000         46.900002
# 2                        0.000000        98.000000         23.299999
# 3                        0.000000        75.000000         40.299999
# 4                        0.000000        -1.000000         32.700001
# 5                        0.000000        -1.000000         23.200001
# 6                        0.000000        54.000000         30.600000
# 7                        0.000000        69.000000         29.700001
# 8                        0.000000        32.000000         32.500000
# 9                        0.000000        -1.000000         24.900000
#
#    SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 0           49.299999          145.399994            154.800003
# 1           46.900002          147.399994            147.399994
# 2           24.500000           49.799999             52.700001
# 3           42.799999           98.699997            105.500000
# 4           34.700001           81.199997             84.099998
# 5           24.700001           52.599998             54.200001
# 6           32.099998           82.800003             89.099998
# 7           31.700001           93.400002             99.699997
# 8           33.700001          101.900002            105.900002
# 9           28.000000           38.900002             42.400002
#
#    SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 0        816300.500000          869296.312500        0.000000
# 1       1218112.000000         1218112.000000        0.000000
# 2        586358.875000          615255.375000        0.000000
# 3       3221754.000000         3419861.500000        0.000000
# 4        960987.812500         1019654.313000        0.000000
# 5        905750.375000          963968.187500        0.000000
# 6       3466465.000000         3631240.750000        0.000000
# 7       2924362.000000         3121704.500000        0.000000
# 8       1375978.875000         1430023.000000        0.000000
# 9        561473.875000          630412.625000        0.000000
#
#    Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  \
# 0     239244.000000      816301.000000            0.000000          0.000000
# 1     357008.187500     1218112.000000            0.000000          0.000000
# 2      89109.898440      304043.000000         2823.159912     282316.000000
# 3     631404.312500     2154352.000000        10674.020510    1067402.000000
# 4     192884.093800      658121.000000         3028.669922     302867.000000
# 5     154136.406300      525913.000000         3798.369873     379837.000000
# 6     803639.687500     2742019.000000         7244.459961     724446.000000
# 7     857081.375000     2924362.000000            0.000000          0.000000
# 8     403017.500000     1375096.000000            8.830000        883.000000
# 9      40037.800780      136609.000000         4248.649902     424865.000000
#
#    TotalGHGEmissions  GHGEmissionsIntensity
# 0           5.690000               0.270000
# 1           8.490000               0.330000
# 2          17.110000               0.680000
# 3          71.710000               0.970000
# 4          20.670000               0.570000
# 5          23.840000               0.610000
# 6          57.590000               0.420000
# 7          20.390000               0.170000
# 8           9.630000               0.180000
# 9          23.520000               1.040000

# %%
dataset.dtypes
# Out:
# OSEBuildingID                         int64
# BuildingType                       category
# PrimaryPropertyType                category
# ZipCode                            category
# CouncilDistrictCode                category
# Neighborhood                       category
# YearBuilt                             int64
# NumberofBuildings                   float64
# NumberofFloors                        int64
# PropertyGFATotal                      int64
# PropertyGFAParking                    int64
# PropertyGFABuilding(s)                int64
# LargestPropertyUseType             category
# LargestPropertyUseTypeGFA           float64
# SecondLargestPropertyUseType       category
# SecondLargestPropertyUseTypeGFA     float64
# ThirdLargestPropertyUseType        category
# ThirdLargestPropertyUseTypeGFA      float64
# ENERGYSTARScore                     float64
# SiteEUI(kBtu/sf)                    float64
# SiteEUIWN(kBtu/sf)                  float64
# SourceEUI(kBtu/sf)                  float64
# SourceEUIWN(kBtu/sf)                float64
# SiteEnergyUse(kBtu)                 float64
# SiteEnergyUseWN(kBtu)               float64
# SteamUse(kBtu)                      float64
# Electricity(kWh)                    float64
# Electricity(kBtu)                   float64
# NaturalGas(therms)                  float64
# NaturalGas(kBtu)                    float64
# TotalGHGEmissions                   float64
# GHGEmissionsIntensity               float64
# dtype: object

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)
pd.set_option('display.max_columns', None)

dataset.describe()
# Out:
#        OSEBuildingID  YearBuilt  NumberofBuildings  NumberofFloors  \
# count           3157       3157               3157            3157
# mean           21353       1969                  1               5
# std            12033         33                  1               6
# min                1       1900                  1               0
# 25%            20073       1948                  1               2
# 50%            23161       1975                  1               4
# 75%            25995       1997                  1               5
# max            50226       2015                 27              99
#
#        PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# count              3157                3157                    3157
# mean              92195                8352                   83843
# std              151836               33150                  134458
# min               11285                   0                    3636
# 25%               28185                   0                   27494
# 50%               43606                   0                   42401
# 75%               90920                   0                   84147
# max             2200000              512608                 2200000
#
#        LargestPropertyUseTypeGFA  SecondLargestPropertyUseTypeGFA  \
# count                       3157                             3157
# mean                       76003                            14489
# std                       124503                            40162
# min                         5656                                0
# 25%                        24948                                0
# 50%                        38879                                0
# 75%                        75154                            11317
# max                      1719643                           639931
#
#        ThirdLargestPropertyUseTypeGFA  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# count                            3157             3157              3157
# mean                             2166               50                55
# std                             13514               38                56
# min                                 0               -1                 1
# 25%                                 0                1                28
# 50%                                 0               60                39
# 75%                                 0               85                61
# max                            459748              100               834
#
#        SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# count                3157                3157                  3157
# mean                   58                 137                   141
# std                    57                 140                   140
# min                     0                   4                     0
# 25%                    30                  76                    79
# 50%                    41                  98                   103
# 75%                    66                 146                   151
# max                   834                2620                  2620
#
#        SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# count                 3157                   3157            3157
# mean               5219985                5373465          248187
# std               15995471               16372763         3723416
# min                  57133                      0               0
# 25%                 934981                 986820               0
# 50%                1791698                1894319               0
# 75%                4225362                4416910               0
# max              448385312              471613856       134943456
#
#        Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# count              3157               3157                3157
# mean            1047945            3575589               13962
# std             2900695            9897173               69164
# min                   0                  0                   0
# 25%              188210             642173                   0
# 50%              346086            1180845                3256
# 75%              841156            2870024               11885
# max            80460872          274532495             2979090
#
#        NaturalGas(kBtu)  TotalGHGEmissions  GHGEmissionsIntensity
# count              3157               3157                   3157
# mean            1396205                118                      1
# std             6916366                519                      2
# min                   0                  0                      0
# 25%                   0                 10                      0
# 50%              325617                 34                      1
# 75%             1188459                 94                      1
# max           297909000              16871                     34

# %% [markdown]
# ### 1) Plot kWh / kBtu and therms / kBtu

# %%
print("Natural Gas")
dataset.plot.scatter("NaturalGas(therms)", "NaturalGas(kBtu)", c="g")
# Out:
# Natural Gas
# <AxesSubplot:xlabel='NaturalGas(therms)', ylabel='NaturalGas(kBtu)'>

# %%
# Easy Linear Regression : x = kWh y = kBtu
print("Electricity")
plt.plot(dataset["Electricity(kWh)"], dataset["Electricity(kBtu)"], "ro", markersize=4)
plt.show()
# Out:
# Electricity

# %%
print(
    "After checking that the Electricity in kWh = 3.412 Electricity in kBtu and that NaturalGas(therms) = 100 NaturalGas(kBtu) ; we drop the kWh and therms.")
dataset_v1 = dataset.drop(columns=["Electricity(kWh)", "NaturalGas(therms)"])
# Out:
# After checking that the Electricity in kWh = 3.412 Electricity in kBtu and that NaturalGas(therms) = 100 NaturalGas(kBtu) ; we drop the kWh and therms.

# %% [markdown]
# We tried to implement linear regression to verify that :
# - the Electricity in kWh x 3.412 = Electricity in kBtu,
# - the NaturalGas in Therms x 99.98 = NaturalGas in kBtu.

# %% [markdown]
# #### Manual Linear Regression

# %%
# Linear Regression "manually" / we transform the dataset into matrices to compute theta
X = np.matrix([np.ones(dataset.shape[0]), dataset["Electricity(kWh)"]]).T
Y = np.matrix(dataset["Electricity(kBtu)"]).T
# Out:
# C:\Users\athen\AppData\Local\Temp\ipykernel_10276\2136336263.py:2: PendingDeprecationWarning: the matrix subclass is not the recommended way to represent matrices or deal with linear algebra (see https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html). Please adjust your code to use regular ndarray.
#   X = np.matrix([np.ones(dataset.shape[0]), dataset["Electricity(kWh)"]]).T

# %%
np.set_printoptions(suppress=True)  # remove scientific notation
X[:10]
# Out:
# matrix([[     1.     , 239244.     ],
#         [     1.     , 357008.1875 ],
#         [     1.     ,  89109.89844],
#         [     1.     , 631404.3125 ],
#         [     1.     , 192884.0938 ],
#         [     1.     , 154136.4063 ],
#         [     1.     , 803639.6875 ],
#         [     1.     , 857081.375  ],
#         [     1.     , 403017.5    ],
#         [     1.     ,  40037.80078]])

# %%
# Computing the exact value of the parameter theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(Y)

# displaying theta with a = slope ; and b = y-intercept
print(theta)

# we test Y = aX + b for X = 10
print(theta.item(0) + theta.item(1) * 10)
# Out:
# [[0.01074224]
#  [3.412     ]]
# 34.13074219245941

# %%
plt.xlabel("Electricity(kWh)")
plt.ylabel("Electricity(kBtu)")

x_min = 0
x_max = 200000000
y_min = theta.item(0)
y_max = theta.item(0) + x_max * theta.item(1)

plt.plot([x_min, x_max], [y_min, y_max], linestyle="--", c="#000000")
plt.plot(dataset["Electricity(kWh)"], dataset["Electricity(kBtu)"], "ro", markersize=4)

plt.show()

# %% [markdown]
# #### Automatic Linear Regression

# %%
# 0) Getting data and Sampling
from sklearn.linear_model import LinearRegression

X = dataset["Electricity(kWh)"]
y = dataset["Electricity(kBtu)"]  # target

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# reshape to get 2D array instead of 1D array.
# values to get a numpy array instead of a pandas Series
X_train = X_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)
y_train = y_train.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1)

# %%
X_train
# Out:
# array([[279201.4063],
#        [268255.    ],
#        [313922.5   ],
#        ...,
#        [384925.5   ],
#        [550539.8125],
#        [299459.0938]])

# %%
# 1) Training Linear Regression and Evaluating
reg = LinearRegression().fit(X_train, y_train)
prediction_score = reg.score(X_test, y_test)
#print("Accuracy is : %.2f" % (100 * prediction_score))
print('Accuracy is : {:.0%}'.format(prediction_score))

# 2) Trying to predict a value
reg.predict([[10]])  # if X = 10 kWh then Y = 34.12 kBtu ;)
# Out:
# Accuracy is : 100%
# array([[34.12971401]])

# %%
print("Electricity prediction")
plt.plot(reg.predict(X_test), y_test, "ro", markersize=4)
plt.show()
# Out:
# Electricity prediction

# %% [markdown]
# #### Conclusion :
# This Linear Rregression was for training purposes.
# We remove the redundant features like Electricity in kWh and NaturalGas in Therms.
#
# Thanks to the correlation matrix below, we will be able to choose the features that will help our prediction model.

# %% [markdown]
# for column in dataset_v1.select_dtypes(['int32', 'float64']).columns:
#     plt.figure(figsize=(12,6))
#     plt.title('Distribution de ' + column)
#     sns.histplot(data[column], bins=20)

# %% [markdown]
# ### 2) Correlation Matrix

# %% [markdown]
# #### 2.1) Correlation between energy variables

# %%
all_energy_features = ["SiteEUI(kBtu/sf)", "SiteEUIWN(kBtu/sf)", "SourceEUI(kBtu/sf)", "SourceEUIWN(kBtu/sf)",
                       "SiteEnergyUse(kBtu)", "SiteEnergyUseWN(kBtu)", "SteamUse(kBtu)", "Electricity(kBtu)",
                       "NaturalGas(kBtu)", "TotalGHGEmissions", "GHGEmissionsIntensity"]

# %%
# exploration : matrice corrélation et corrélation entre categorielles et quantitatives (GHGE corrélé avec var consom E (elctricity, steam etc)
# predict : consomation bat puis avec ca predire l'emission CO2
# 1) prediction consommation sur l'énergie puis predire CO2 (le + long le +complexe)
# categories batiments mal ecrites / numeriques incohérentes

# %%
# we create a dataframe with all the energy features.
df_to_corr = dataset_v1[all_energy_features]

# we assign the type float to all the values of the matrix
df_to_corr = df_to_corr.astype(float)
corr_df = df_to_corr.corr(method='spearman')

print("We display here the correlation matrix without options to justify the display below.")
plt.figure(figsize=(10, 8))
plt.title('Correlation matrix for energy features.')
sns.heatmap(corr_df, annot=True, vmin=-1, cmap='coolwarm')
plt.show()
# Out:
# We display here the correlation matrix without options to justify the display below.

# %%
plt.figure(figsize=(10, 8))
sns.set(font_scale=1)
plt.title('Correlation matrix for energy features with upper triangle masked.')

# to hide the upper triangle of the matrix
trimask = np.zeros_like(corr_df)
trimask[np.triu_indices_from(trimask)] = True
sns.heatmap(corr_df, annot=True, mask=trimask | (np.abs(corr_df) <= 0.4), vmin=0,
            cmap='coolwarm')  # we don't have negative correlations here

plt.show()
# Out:
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\rcmod.py:400: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %% [markdown]
# **Interpretation** :
#
# - We can see a strong correlation between the variables.
#
#
# **Conclusion** :
# - We will drop the variables Weather Normalized,
# - We drop the variable GHGEmissionsIntensity.

# %% [markdown]
# #### 2.2) Correlation matrix with all features

# %%
numeric_columns = dataset_v1.select_dtypes(include=['int64', 'float64']).columns
corr = dataset_v1[numeric_columns].corr()

plt.figure(figsize=(13, 11))
sns.set(font_scale=1)
plt.title('Correlation matrix for all numeric features.')

# to hide the upper triangle of the matrix
trimask = np.zeros_like(corr)
trimask[np.triu_indices_from(trimask)] = True
sns.heatmap(corr, annot=True, vmin=0, cmap='coolwarm')  # we don't have negative correlations here

plt.show()

# %% [markdown]
# dataset_v1.columns

# %%
print("ASK MENTOR INTERPRETATION CORR MATRIX")
# carac bat interess pour predirection / redtirer quand trop correlees entre elles
# Out:
# ASK MENTOR INTERPRETATION CORR MATRIX

# %% [markdown]
# **Interpretation** :
#
# - We can see a strong correlation between the variables.
#
#
# **Conclusion** :
# - We will drop the variables Weather Normalized,
# - We drop the variable GHGEmissionsIntensity.

# %%
correlated_features = ["SiteEUI(kBtu/sf)", 'SiteEUIWN(kBtu/sf)', 'SiteEnergyUseWN(kBtu)', 'SourceEUI(kBtu/sf)',
                       'SourceEUIWN(kBtu/sf)', "GHGEmissionsIntensity"]

# %%
dataset_v2 = dataset_v1.drop(columns=correlated_features, inplace=False)

# %% [markdown]
# ### 3) Distribution of quantitative variables

# %% [markdown]
# #### 3.1) Boxplot per primary property type

# %%
dataset_v2.dtypes
# Out:
# OSEBuildingID                         int64
# BuildingType                       category
# PrimaryPropertyType                category
# ZipCode                            category
# CouncilDistrictCode                category
# Neighborhood                       category
# YearBuilt                             int64
# NumberofBuildings                   float64
# NumberofFloors                        int64
# PropertyGFATotal                      int64
# PropertyGFAParking                    int64
# PropertyGFABuilding(s)                int64
# LargestPropertyUseType             category
# LargestPropertyUseTypeGFA           float64
# SecondLargestPropertyUseType       category
# SecondLargestPropertyUseTypeGFA     float64
# ThirdLargestPropertyUseType        category
# ThirdLargestPropertyUseTypeGFA      float64
# ENERGYSTARScore                     float64
# SiteEnergyUse(kBtu)                 float64
# SteamUse(kBtu)                      float64
# Electricity(kBtu)                   float64
# NaturalGas(kBtu)                    float64
# TotalGHGEmissions                   float64
# dtype: object

# %%
from functions import *

print("After removing outliers, we display boxplot per energy feature and per Primary Property Type.")
print(
    "We suppose that a K-12 School has different energy needed compared to a hospital, so the boxplot must represent that difference.")

data_plot = dataset_v2.copy()
data_plot.loc[data_plot["ENERGYSTARScore"] == -1] = np.nan

list_features_to_plot = data_plot.select_dtypes(include="number").columns.tolist()
list_features_to_plot.remove("OSEBuildingID")
# Out:
# After removing outliers, we display boxplot per energy feature and per Primary Property Type.
# We suppose that a K-12 School has different energy needed compared to a hospital, so the boxplot must represent that difference.

# %%
display_boxplot_per_feature(data_plot, list_features_to_plot, "PrimaryPropertyType")
# Out:
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\rcmod.py:400: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %% [markdown]
# #### 3.2) Histograms

# %%
data_plot
# Out:
#       OSEBuildingID          BuildingType          PrimaryPropertyType  \
# 0             25006  Multifamily LR (1-4)         Low-Rise Multifamily
# 1               NaN                   NaN                          NaN
# 2             25028  Multifamily LR (1-4)         Low-Rise Multifamily
# 3             25046  Multifamily HR (10+)        High-Rise Multifamily
# 4               NaN                   NaN                          NaN
# ...             ...                   ...                          ...
# 3152            NaN                   NaN                          NaN
# 3153          21124  Multifamily LR (1-4)         Low-Rise Multifamily
# 3154          21125        NonResidential  Small- and Mid-Sized Office
# 3155          21129        NonResidential                 Retail Store
# 3156            NaN                   NaN                          NaN
#
#       ZipCode CouncilDistrictCode      Neighborhood  YearBuilt  \
# 0     98112.0                   3           central       1978
# 1         NaN                 NaN               NaN        NaN
# 2     98144.0                   2  greater duwamish       1925
# 3     98144.0                   2  greater duwamish       1971
# 4         NaN                 NaN               NaN        NaN
# ...       ...                 ...               ...        ...
# 3152      NaN                 NaN               NaN        NaN
# 3153  98103.0                   6        lake union       1907
# 3154  98103.0                   6        lake union       2001
# 3155  98103.0                   6        lake union       1911
# 3156      NaN                 NaN               NaN        NaN
#
#       NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0                     1               3             20739                   0
# 1                   NaN             NaN               NaN                 NaN
# 2                     1               3             25120                   0
# 3                     1              15             73898                   0
# 4                   NaN             NaN               NaN                 NaN
# ...                 ...             ...               ...                 ...
# 3152                NaN             NaN               NaN                 NaN
# 3153                  1               4             36660                   0
# 3154                  1               5             33740                6010
# 3155                  1               2             20516                   0
# 3156                NaN             NaN               NaN                 NaN
#
#       PropertyGFABuilding(s) LargestPropertyUseType  \
# 0                      20739    Multifamily Housing
# 1                        NaN                    NaN
# 2                      25120    Multifamily Housing
# 3                      73898    Multifamily Housing
# 4                        NaN                    NaN
# ...                      ...                    ...
# 3152                     NaN                    NaN
# 3153                   36660    Multifamily Housing
# 3154                   27730                 Office
# 3155                   20516           Retail Store
# 3156                     NaN                    NaN
#
#       LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# 0                         17628                         None
# 1                           NaN                          NaN
# 2                         25120                         None
# 3                         79912                         None
# 4                           NaN                          NaN
# ...                         ...                          ...
# 3152                        NaN                          NaN
# 3153                      36660                         None
# 3154                      15908                 Retail Store
# 3155                      10155                        Hotel
# 3156                        NaN                          NaN
#
#       SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# 0                                   0                        None
# 1                                 NaN                         NaN
# 2                                   0                        None
# 3                                   0                        None
# 4                                 NaN                         NaN
# ...                               ...                         ...
# 3152                              NaN                         NaN
# 3153                                0                        None
# 3154                             8762                     Parking
# 3155                             8000                        None
# 3156                              NaN                         NaN
#
#       ThirdLargestPropertyUseTypeGFA  ENERGYSTARScore  SiteEnergyUse(kBtu)  \
# 0                                  0               19               816300
# 1                                NaN              NaN                  NaN
# 2                                  0               98               586359
# 3                                  0               75              3221754
# 4                                NaN              NaN                  NaN
# ...                              ...              ...                  ...
# 3152                             NaN              NaN                  NaN
# 3153                               0               98               930368
# 3154                            1500               79              1291405
# 3155                               0               98              1021797
# 3156                             NaN              NaN                  NaN
#
#       SteamUse(kBtu)  Electricity(kBtu)  NaturalGas(kBtu)  TotalGHGEmissions
# 0                  0             816301                 0                  6
# 1                NaN                NaN               NaN                NaN
# 2                  0             304043            282316                 17
# 3                  0            2154352           1067402                 72
# 4                NaN                NaN               NaN                NaN
# ...              ...                ...               ...                ...
# 3152             NaN                NaN               NaN                NaN
# 3153               0             517619            412749                 26
# 3154               0            1291405                 0                  9
# 3155               0             264984            756812                 42
# 3156             NaN                NaN               NaN                NaN
#
# [3157 rows x 24 columns]

# %%
dataset_v2
# Out:
#       OSEBuildingID          BuildingType          PrimaryPropertyType  \
# 0             25006  Multifamily LR (1-4)         Low-Rise Multifamily
# 1             25025        NonResidential                    Warehouse
# 2             25028  Multifamily LR (1-4)         Low-Rise Multifamily
# 3             25046  Multifamily HR (10+)        High-Rise Multifamily
# 4             25047  Multifamily LR (1-4)         Low-Rise Multifamily
# ...             ...                   ...                          ...
# 3152          21122        NonResidential           Mixed Use Property
# 3153          21124  Multifamily LR (1-4)         Low-Rise Multifamily
# 3154          21125        NonResidential  Small- and Mid-Sized Office
# 3155          21129        NonResidential                 Retail Store
# 3156          50226    Nonresidential COS           Mixed Use Property
#
#       ZipCode CouncilDistrictCode      Neighborhood  YearBuilt  \
# 0     98112.0                   3           central       1978
# 1     98144.0                   3  greater duwamish       1928
# 2     98144.0                   2  greater duwamish       1925
# 3     98144.0                   2  greater duwamish       1971
# 4     98108.0                   2  greater duwamish       2001
# ...       ...                 ...               ...        ...
# 3152  98103.0                   6        lake union       2001
# 3153  98103.0                   6        lake union       1907
# 3154  98103.0                   6        lake union       2001
# 3155  98103.0                   6        lake union       1911
# 3156  98108.0                   2  greater duwamish       1938
#
#       NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0                     1               3             20739                   0
# 1                     1               2             25955                   0
# 2                     1               3             25120                   0
# 3                     1              15             73898                   0
# 4                     1               3             36383                7030
# ...                 ...             ...               ...                 ...
# 3152                  5               3             41827                9226
# 3153                  1               4             36660                   0
# 3154                  1               5             33740                6010
# 3155                  1               2             20516                   0
# 3156                  1               1             18258                   0
#
#       PropertyGFABuilding(s)      LargestPropertyUseType  \
# 0                      20739         Multifamily Housing
# 1                      25955  Non-Refrigerated Warehouse
# 2                      25120         Multifamily Housing
# 3                      73898         Multifamily Housing
# 4                      29353         Multifamily Housing
# ...                      ...                         ...
# 3152                   32601         Multifamily Housing
# 3153                   36660         Multifamily Housing
# 3154                   27730                      Office
# 3155                   20516                Retail Store
# 3156                   18258          Other - Recreation
#
#       LargestPropertyUseTypeGFA    SecondLargestPropertyUseType  \
# 0                         17628                            None
# 1                         14150                Other - Services
# 2                         25120                            None
# 3                         79912                            None
# 4                         25153                          Office
# ...                         ...                             ...
# 3152                      14273                          Office
# 3153                      36660                            None
# 3154                      15908                    Retail Store
# 3155                      10155                           Hotel
# 3156                       8271  Fitness Center/Health Club/Gym
#
#       SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# 0                                   0                        None
# 1                                8745                      Office
# 2                                   0                        None
# 3                                   0                        None
# 4                                4200                     Parking
# ...                               ...                         ...
# 3152                            14128                     Parking
# 3153                                0                        None
# 3154                             8762                     Parking
# 3155                             8000                        None
# 3156                             8000          Pre-school/Daycare
#
#       ThirdLargestPropertyUseTypeGFA  ENERGYSTARScore  SiteEnergyUse(kBtu)  \
# 0                                  0               19               816300
# 1                               3060               -1              1218112
# 2                                  0               98               586359
# 3                                  0               75              3221754
# 4                                  0               -1               960988
# ...                              ...              ...                  ...
# 3152                            9680               -1              4193371
# 3153                               0               98               930368
# 3154                            1500               79              1291405
# 3155                               0               98              1021797
# 3156                            1108               -1              1152896
#
#       SteamUse(kBtu)  Electricity(kBtu)  NaturalGas(kBtu)  TotalGHGEmissions
# 0                  0             816301                 0                  6
# 1                  0            1218112                 0                  8
# 2                  0             304043            282316                 17
# 3                  0            2154352           1067402                 72
# 4                  0             658121            302867                 21
# ...              ...                ...               ...                ...
# 3152               0            2439095           1754275                110
# 3153               0             517619            412749                 26
# 3154               0            1291405                 0                  9
# 3155               0             264984            756812                 42
# 3156               0             432554            720342                 41
#
# [3157 rows x 24 columns]

# %%
len(list_features_to_plot)
# Out:
# 15

# %%
data = dataset_v2.copy()
data = data[list_features_to_plot]

X = data.values

# %%
X
# Out:
# array([[   1978.    ,       1.    ,       3.    , ...,  816301.    ,
#               0.    ,       5.69  ],
#        [   1928.    ,       1.    ,       2.    , ..., 1218112.    ,
#               0.    ,       8.49  ],
#        [   1925.    ,       1.    ,       3.    , ...,  304043.    ,
#          282316.    ,      17.11  ],
#        ...,
#        [   2001.    ,       1.    ,       5.    , ..., 1291405.    ,
#               0.    ,       9.    ],
#        [   1911.    ,       1.    ,       2.    , ...,  264984.    ,
#          756812.    ,      42.04  ],
#        [   1938.    ,       1.    ,       1.    , ...,  432554.2475,
#          720341.9922,      41.27  ]])

# %%
data
# Out:
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 0          1978                  1               3             20739
# 1          1928                  1               2             25955
# 2          1925                  1               3             25120
# 3          1971                  1              15             73898
# 4          2001                  1               3             36383
# ...         ...                ...             ...               ...
# 3152       2001                  5               3             41827
# 3153       1907                  1               4             36660
# 3154       2001                  1               5             33740
# 3155       1911                  1               2             20516
# 3156       1938                  1               1             18258
#
#       PropertyGFAParking  PropertyGFABuilding(s)  LargestPropertyUseTypeGFA  \
# 0                      0                   20739                      17628
# 1                      0                   25955                      14150
# 2                      0                   25120                      25120
# 3                      0                   73898                      79912
# 4                   7030                   29353                      25153
# ...                  ...                     ...                        ...
# 3152                9226                   32601                      14273
# 3153                   0                   36660                      36660
# 3154                6010                   27730                      15908
# 3155                   0                   20516                      10155
# 3156                   0                   18258                       8271
#
#       SecondLargestPropertyUseTypeGFA  ThirdLargestPropertyUseTypeGFA  \
# 0                                   0                               0
# 1                                8745                            3060
# 2                                   0                               0
# 3                                   0                               0
# 4                                4200                               0
# ...                               ...                             ...
# 3152                            14128                            9680
# 3153                                0                               0
# 3154                             8762                            1500
# 3155                             8000                               0
# 3156                             8000                            1108
#
#       ENERGYSTARScore  SiteEnergyUse(kBtu)  SteamUse(kBtu)  Electricity(kBtu)  \
# 0                  19               816300               0             816301
# 1                  -1              1218112               0            1218112
# 2                  98               586359               0             304043
# 3                  75              3221754               0            2154352
# 4                  -1               960988               0             658121
# ...               ...                  ...             ...                ...
# 3152               -1              4193371               0            2439095
# 3153               98               930368               0             517619
# 3154               79              1291405               0            1291405
# 3155               98              1021797               0             264984
# 3156               -1              1152896               0             432554
#
#       NaturalGas(kBtu)  TotalGHGEmissions
# 0                    0                  6
# 1                    0                  8
# 2               282316                 17
# 3              1067402                 72
# 4               302867                 21
# ...                ...                ...
# 3152           1754275                110
# 3153            412749                 26
# 3154                 0                  9
# 3155            756812                 42
# 3156            720342                 41
#
# [3157 rows x 15 columns]

# %%
fig = plt.figure(figsize=(20, 12)) # 16 12
for feat_idx in range(data.shape[1]):
    ax = fig.add_subplot(3,5, (feat_idx + 1)) # subplot : The first argument is the number of plots in each row and the second the number of plots per column (see also the matplotlib.pyplot.subplot documentation).
    # here 15 graphs so 3*5
    h = ax.hist(X[:, feat_idx], bins=50, color='steelblue', density=True, edgecolor='none') # normalisé + bordure
    ax.set_title(data.columns[feat_idx], fontsize=13)

# %%
display_distribution_per_feature(data_plot, list_features_to_plot, 10)

# %%
dataset_v2.columns
# Out:
# Index(['OSEBuildingID', 'BuildingType', 'PrimaryPropertyType', 'ZipCode',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'LargestPropertyUseType',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseType',
#        'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseType',
#        'ThirdLargestPropertyUseTypeGFA', 'ENERGYSTARScore',
#        'SiteEnergyUse(kBtu)', 'SteamUse(kBtu)', 'Electricity(kBtu)',
#        'NaturalGas(kBtu)', 'TotalGHGEmissions'],
#       dtype='object')

# %% [markdown]
# #### 3.3) Distribution

# %%
dataset_v2.dtypes
# Out:
# OSEBuildingID                         int64
# BuildingType                       category
# PrimaryPropertyType                category
# ZipCode                            category
# CouncilDistrictCode                category
# Neighborhood                       category
# YearBuilt                             int64
# NumberofBuildings                   float64
# NumberofFloors                        int64
# PropertyGFATotal                      int64
# PropertyGFAParking                    int64
# PropertyGFABuilding(s)                int64
# LargestPropertyUseType             category
# LargestPropertyUseTypeGFA           float64
# SecondLargestPropertyUseType       category
# SecondLargestPropertyUseTypeGFA     float64
# ThirdLargestPropertyUseType        category
# ThirdLargestPropertyUseTypeGFA      float64
# ENERGYSTARScore                     float64
# SiteEnergyUse(kBtu)                 float64
# SteamUse(kBtu)                      float64
# Electricity(kBtu)                   float64
# NaturalGas(kBtu)                    float64
# TotalGHGEmissions                   float64
# dtype: object

# %%
features_for_prediction = ["YearBuilt", "CouncilDistrictCode", "Neighborhood", "NumberofBuildings", "NumberofFloors",
                           "BuildingType", "PrimaryPropertyType", "LargestPropertyUseType",
                           "SecondLargestPropertyUseType", "ThirdLargestPropertyUseType", "PropertyGFABuilding(s)",
                           "LargestPropertyUseTypeGFA", "SecondLargestPropertyUseTypeGFA",
                           "ThirdLargestPropertyUseTypeGFA"]

densite(data_plot[list_features_to_plot])
# Out:
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [raw]
# # nettoyer : filtrer en ligne / quelques graphiques pour la presentation et mieux visualier / pour justifier des filtres

# %% [markdown]
# ### 4) Logarithmic transformation of the variables to predict

# %% [markdown]
# #### 4.1) Log Graphs ??

# %%
print("We check the effect of a log transformation on the variable we want to predict.")
#all_log_transformations = compute_log_for_feature(dataset_v2, "SiteEnergyUse(kBtu)")
#log_distribution(all_log_transformations)
# Out:
# We check the effect of a log transformation on the variable we want to predict.

# %% [markdown]
# #### 4.2) Log transformation for the features to predict

# %%
features_to_predict = [
    "SiteEnergyUse(kBtu)",
    "SteamUse(kBtu)",
    "Electricity(kBtu)",
    "NaturalGas(kBtu)",
    "TotalGHGEmissions"]

print(features_to_predict)
# Out:
# ['SiteEnergyUse(kBtu)', 'SteamUse(kBtu)', 'Electricity(kBtu)', 'NaturalGas(kBtu)', 'TotalGHGEmissions']

# %%
print("These are the features that need a transformation :")
skew_features = get_features_skewness(dataset_v2)
print(skew_features)
# Out:
# These are the features that need a transformation :
# ['NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking', 'PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseTypeGFA', 'SiteEnergyUse(kBtu)', 'SteamUse(kBtu)', 'Electricity(kBtu)', 'NaturalGas(kBtu)', 'TotalGHGEmissions']

# %%
print("Before :")
densite(dataset_v2[skew_features])
# Out:
# Before :
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
print("Trying different log transformations :")
test_log = compute_log_effect_on_skewness(dataset_v2, skew_features)
# Out:
# Trying different log transformations :

# %%
pd.set_option('display.float_format', lambda x: '%.6f' % x)
display(test_log)
# Out:
#                            feature       ln    log-2   log-10
# 0                NumberofBuildings 8.414544 8.414544 8.414544
# 0                   NumberofFloors 0.817899 0.817899 0.817899
# 0                 PropertyGFATotal 1.124664 1.124664 1.124664
# 0               PropertyGFAParking 2.002417 2.002417 2.002417
# 0           PropertyGFABuilding(s) 1.135171 1.135171 1.135171
# 0        LargestPropertyUseTypeGFA 1.008123 1.008123 1.008123
# 0  SecondLargestPropertyUseTypeGFA 0.192145 0.192145 0.192145
# 0   ThirdLargestPropertyUseTypeGFA 1.862996 1.862996 1.862996
# 0              SiteEnergyUse(kBtu) 0.773125 0.773125 0.773125
# 0                   SteamUse(kBtu) 4.956494 4.956494 4.956494
# 0                Electricity(kBtu) 0.248761 0.248761 0.248761
# 0                 NaturalGas(kBtu) 0.442483 0.442483 0.442483
# 0                TotalGHGEmissions 0.402789 0.402789 0.402789

# %%
dataset_v3 = log_transformation(dataset_v2, skew_features)
display(dataset_v3)
# Out:
# Log-transformation of the variables to predict.
#       OSEBuildingID          BuildingType          PrimaryPropertyType  \
# 0             25006  Multifamily LR (1-4)         Low-Rise Multifamily
# 1             25025        NonResidential                    Warehouse
# 2             25028  Multifamily LR (1-4)         Low-Rise Multifamily
# 3             25046  Multifamily HR (10+)        High-Rise Multifamily
# 4             25047  Multifamily LR (1-4)         Low-Rise Multifamily
# ...             ...                   ...                          ...
# 3152          21122        NonResidential           Mixed Use Property
# 3153          21124  Multifamily LR (1-4)         Low-Rise Multifamily
# 3154          21125        NonResidential  Small- and Mid-Sized Office
# 3155          21129        NonResidential                 Retail Store
# 3156          50226    Nonresidential COS           Mixed Use Property
#
#       ZipCode CouncilDistrictCode      Neighborhood  YearBuilt  \
# 0     98112.0                   3           central       1978
# 1     98144.0                   3  greater duwamish       1928
# 2     98144.0                   2  greater duwamish       1925
# 3     98144.0                   2  greater duwamish       1971
# 4     98108.0                   2  greater duwamish       2001
# ...       ...                 ...               ...        ...
# 3152  98103.0                   6        lake union       2001
# 3153  98103.0                   6        lake union       1907
# 3154  98103.0                   6        lake union       2001
# 3155  98103.0                   6        lake union       1911
# 3156  98108.0                   2  greater duwamish       1938
#
#       NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0              1.000000               3             20739                   0
# 1              1.000000               2             25955                   0
# 2              1.000000               3             25120                   0
# 3              1.000000              15             73898                   0
# 4              1.000000               3             36383                7030
# ...                 ...             ...               ...                 ...
# 3152           5.000000               3             41827                9226
# 3153           1.000000               4             36660                   0
# 3154           1.000000               5             33740                6010
# 3155           1.000000               2             20516                   0
# 3156           1.000000               1             18258                   0
#
#       PropertyGFABuilding(s)      LargestPropertyUseType  \
# 0                      20739         Multifamily Housing
# 1                      25955  Non-Refrigerated Warehouse
# 2                      25120         Multifamily Housing
# 3                      73898         Multifamily Housing
# 4                      29353         Multifamily Housing
# ...                      ...                         ...
# 3152                   32601         Multifamily Housing
# 3153                   36660         Multifamily Housing
# 3154                   27730                      Office
# 3155                   20516                Retail Store
# 3156                   18258          Other - Recreation
#
#       LargestPropertyUseTypeGFA    SecondLargestPropertyUseType  \
# 0                  17628.000000                            None
# 1                  14150.000000                Other - Services
# 2                  25120.000000                            None
# 3                  79912.000000                            None
# 4                  25153.000000                          Office
# ...                         ...                             ...
# 3152               14273.000000                          Office
# 3153               36660.000000                            None
# 3154               15908.000000                    Retail Store
# 3155               10155.000000                           Hotel
# 3156                8271.000000  Fitness Center/Health Club/Gym
#
#       SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# 0                            0.000000                        None
# 1                         8745.000000                      Office
# 2                            0.000000                        None
# 3                            0.000000                        None
# 4                         4200.000000                     Parking
# ...                               ...                         ...
# 3152                     14128.000000                     Parking
# 3153                         0.000000                        None
# 3154                      8762.000000                     Parking
# 3155                      8000.000000                        None
# 3156                      8000.000000          Pre-school/Daycare
#
#       ThirdLargestPropertyUseTypeGFA  ENERGYSTARScore  SiteEnergyUse(kBtu)  \
# 0                           0.000000        19.000000        816300.500000
# 1                        3060.000000        -1.000000       1218112.000000
# 2                           0.000000        98.000000        586358.875000
# 3                           0.000000        75.000000       3221754.000000
# 4                           0.000000        -1.000000        960987.812500
# ...                              ...              ...                  ...
# 3152                     9680.000000        -1.000000       4193371.000000
# 3153                        0.000000        98.000000        930368.500000
# 3154                     1500.000000        79.000000       1291405.250000
# 3155                        0.000000        98.000000       1021796.625000
# 3156                     1108.000000        -1.000000       1152896.250000
#
#       SteamUse(kBtu)  Electricity(kBtu)  NaturalGas(kBtu)  TotalGHGEmissions  \
# 0           0.000000      816301.000000          0.000000           5.690000
# 1           0.000000     1218112.000000          0.000000           8.490000
# 2           0.000000      304043.000000     282316.000000          17.110000
# 3           0.000000     2154352.000000    1067402.000000          71.710000
# 4           0.000000      658121.000000     302867.000000          20.670000
# ...              ...                ...               ...                ...
# 3152        0.000000     2439095.000000    1754275.000000         110.170000
# 3153        0.000000      517619.000000     412749.000000          25.530000
# 3154        0.000000     1291405.000000          0.000000           9.000000
# 3155        0.000000      264984.000000     756812.000000          42.040000
# 3156        0.000000      432554.247500     720341.992200          41.270000
#
#       Log-NumberofBuildings  Log-NumberofFloors  Log-PropertyGFATotal  \
# 0                  0.693147            1.386294              9.939819
# 1                  0.693147            1.098612             10.164158
# 2                  0.693147            1.386294             10.131459
# 3                  0.693147            2.772589             11.210455
# 4                  0.693147            1.386294             10.501884
# ...                     ...                 ...                   ...
# 3152               1.791759            1.386294             10.641321
# 3153               0.693147            1.609438             10.509469
# 3154               0.693147            1.791759             10.426469
# 3155               0.693147            1.098612              9.929009
# 3156               0.693147            0.693147              9.812413
#
#       Log-PropertyGFAParking  Log-PropertyGFABuilding(s)  \
# 0                   0.000000                    9.939819
# 1                   0.000000                   10.164158
# 2                   0.000000                   10.131459
# 3                   0.000000                   11.210455
# 4                   8.858084                   10.287184
# ...                      ...                         ...
# 3152                9.129889                   10.392129
# 3153                0.000000                   10.509469
# 3154                8.701346                   10.230306
# 3155                0.000000                    9.929009
# 3156                0.000000                    9.812413
#
#       Log-LargestPropertyUseTypeGFA  Log-SecondLargestPropertyUseTypeGFA  \
# 0                          9.777301                             0.000000
# 1                          9.557541                             9.076352
# 2                         10.131459                             0.000000
# 3                         11.288694                             0.000000
# 4                         10.132772                             8.343078
# ...                             ...                                  ...
# 3152                       9.566195                             9.555985
# 3153                      10.509469                             0.000000
# 3154                       9.674640                             9.078294
# 3155                       9.225820                             8.987322
# 3156                       9.020632                             8.987322
#
#       Log-ThirdLargestPropertyUseTypeGFA  Log-SiteEnergyUse(kBtu)  \
# 0                               0.000000                13.612539
# 1                               8.026497                14.012813
# 2                               0.000000                13.281689
# 3                               0.000000                14.985437
# 4                               0.000000                13.775718
# ...                                  ...                      ...
# 3152                            9.177920                15.249016
# 3153                            0.000000                13.743337
# 3154                            7.313887                14.071242
# 3155                            0.000000                13.837074
# 3156                            7.011214                13.957789
#
#       Log-SteamUse(kBtu)  Log-Electricity(kBtu)  Log-NaturalGas(kBtu)  \
# 0               0.000000              13.612540              0.000000
# 1               0.000000              14.012813              0.000000
# 2               0.000000              12.624928             12.550786
# 3               0.000000              14.583001             13.880739
# 4               0.000000              13.397146             12.621052
# ...                  ...                    ...                   ...
# 3152            0.000000              14.707138             14.377567
# 3153            0.000000              13.156997             12.930597
# 3154            0.000000              14.071242              0.000000
# 3155            0.000000              12.487428             13.536871
# 3156            0.000000              12.977465             13.487483
#
#       Log-TotalGHGEmissions
# 0                  1.900614
# 1                  2.250239
# 2                  2.896464
# 3                  4.286479
# 4                  3.075929
# ...                     ...
# 3152               4.711061
# 3153               3.278276
# 3154               2.302585
# 3155               3.762130
# 3156               3.744078
#
# [3157 rows x 37 columns]

# %%
log_skew_features = ["Log-{}".format(feature) for feature in skew_features]

# %%
log_skew_features
# Out:
# ['Log-NumberofBuildings',
#  'Log-NumberofFloors',
#  'Log-PropertyGFATotal',
#  'Log-PropertyGFAParking',
#  'Log-PropertyGFABuilding(s)',
#  'Log-LargestPropertyUseTypeGFA',
#  'Log-SecondLargestPropertyUseTypeGFA',
#  'Log-ThirdLargestPropertyUseTypeGFA',
#  'Log-SiteEnergyUse(kBtu)',
#  'Log-SteamUse(kBtu)',
#  'Log-Electricity(kBtu)',
#  'Log-NaturalGas(kBtu)',
#  'Log-TotalGHGEmissions']

# %%
print("After :")
densite(dataset_v3[log_skew_features])
# Out:
# After :
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\athen\Anaconda3\envs\P4_OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 5) Saving cleaned dataset

# %%
# We reset the index
final_dataset = dataset_v3.reset_index(drop=True)

# Save
export_path = "./dataset/cleaned/"
export_filename = "2016_Building_Energy_Prediction.csv"
final_dataset.to_csv("{}{}".format(export_path, export_filename), index=False)
